# %% [markdown]
# ##Downloading the datasets

# %%
# !pip install -q kaggle

# %%
mkdir %userprofile%\.kaggle
# Out:
# A subdirectory or file C:\Users\jayanth\.kaggle already exists.

# %%
# !cd kaggle.json ~/.kaggle
# Out:
# The system cannot find the path specified.

# %%
# !kaggle datasets download -d tourist55/alzheimers-dataset-4-class-of-images
# Out:
# Dataset URL: https://www.kaggle.com/datasets/tourist55/alzheimers-dataset-4-class-of-images
# License(s): ODbL-1.0
# alzheimers-dataset-4-class-of-images.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip /content/alzheimers-dataset-4-class-of-images.zip
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ##creating training and testing dataset

# %%
trainPath=r"/content/Alzheimer_s Dataset/train"

# %%
testPath=r"/content/Alzheimer_s Dataset/test"

# %% [markdown]
# ##importing the libraries

# %%
# !pip install matplotlib-venn
# Out:
# Requirement already satisfied: matplotlib-venn in d:\aparna-vface\finalyrproject\system\edit\neurological_disease_predictor\env\lib\site-packages (0.11.10)
# Requirement already satisfied: matplotlib in d:\aparna-vface\finalyrproject\system\edit\neurological_disease_predictor\env\lib\site-packages (from matplotlib-venn) (3.8.4)
# Requirement already satisfied: numpy in d:\aparna-vface\finalyrproject\system\edit\neurological_disease_predictor\env\lib\site-packages (from matplotlib-venn) (1.26.4)
# Requirement already satisfied: scipy in d:\aparna-vface\finalyrproject\system\edit\neurological_disease_predictor\env\lib\site-packages (from matplotlib-venn) (1.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\aparna-vface\finalyrproject\system\edit\neurological_disease_predictor\env\lib\site-packages (from matplotlib->matplotlib-venn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in d:\aparna-vface\finalyrproject\system\edit\neurological_disease_predictor\env\lib\site-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\aparna-vface\finalyrproject\system\edit\neurological_disease_predictor\env\lib\site-packages (from matplotlib->matplotlib-venn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\aparna-vface\finalyrproject\system\edit\neurological_disease_predictor\env\lib\site-packages (from matplotlib->matplotlib-venn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\aparna-vface\finalyrproject\system\edit\neurological_disease_predictor\env\lib\site-packages (from matplotlib->matplotlib-venn) (24.0)
# Requirement already satisfied: pillow>=8 in d:\aparna-vface\finalyrproject\system\edit\neurological_disease_predictor\env\lib\site-packages (from matplotlib->matplotlib-venn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\aparna-vface\finalyrproject\system\edit\neurological_disease_predictor\env\lib\site-packages (from matplotlib->matplotlib-venn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\aparna-vface\finalyrproject\system\edit\neurological_disease_predictor\env\lib\site-packages (from matplotlib->matplotlib-venn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in d:\aparna-vface\finalyrproject\system\edit\neurological_disease_predictor\env\lib\site-packages (from matplotlib->matplotlib-venn) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in d:\aparna-vface\finalyrproject\system\edit\neurological_disease_predictor\env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->matplotlib-venn) (3.18.1)
# Requirement already satisfied: six>=1.5 in d:\aparna-vface\finalyrproject\system\edit\neurological_disease_predictor\env\lib\site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.16.0)

# %%
from tensorflow.keras.layers import Dense,Flatten,Input
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from tensorflow.keras.layers import Dense,Flatten,Input
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
from tensorflow.keras.models import Model

# %%
from tensorflow.keras.preprocessing import image

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img

# %%
from tensorflow.keras.applications.xception import Xception,preprocess_input

# %%
from glob import glob

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ##configuring the image datagenerator class

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG

# %%
IMG_SIZE=180
IMAGE_SIZE=[180,180]
DIM=(IMG_SIZE,IMG_SIZE)
ZOOM=[.99,1.01]
BRIGHT_RANGE=[0.8,1.2]
HORZ_FLIP=True
FILL_MODE="constant"
DATA_FORMAT="channels_last"
WORK_DIR="/content/Alzheimer_s Dataset/train"
work_dr=IDG(rescale=1./255,brightness_range=BRIGHT_RANGE,zoom_range=ZOOM,data_format=DATA_FORMAT,fill_mode=FILL_MODE,
            horizontal_flip=HORZ_FLIP)
train_data_gen=work_dr.flow_from_directory(directory=WORK_DIR,target_size=DIM,batch_size=6500,shuffle=False)
# Out:
# Found 5121 images belonging to 4 classes.

# %%
IMG_SIZE=180
IMAGE_SIZE=[180,180]
DIM=(IMG_SIZE,IMG_SIZE)
ZOOM=[.99,1.01]
BRIGHT_RANGE=[0.8,1.2]
HORZ_FLIP=True
FILL_MODE="constant"
DATA_FORMAT="channels_last"
WORK_DIR="/content/Alzheimer_s Dataset/test"
work_dr=IDG(rescale=1./255,brightness_range=BRIGHT_RANGE,zoom_range=ZOOM,data_format=DATA_FORMAT,fill_mode=FILL_MODE,
            horizontal_flip=HORZ_FLIP)
test_data_gen=work_dr.flow_from_directory(directory=WORK_DIR,target_size=DIM,batch_size=6500,shuffle=False)
# Out:
# Found 1279 images belonging to 4 classes.

# %% [markdown]
# ##handling imbalanced data

# %%
train_data,train_labels=train_data_gen.next()

# %%
print(train_data.shape,train_labels.shape)
# Out:
# (5121, 180, 180, 3) (5121, 4)

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE(random_state=42)

# %%
train_data,train_labels=sm.fit_resample(train_data.reshape(-1,IMG_SIZE * IMG_SIZE *3),train_labels)

# %%
train_data=train_data.reshape(-1,IMG_SIZE,IMG_SIZE,3)

# %%
print(train_data.shape,train_labels.shape)
# Out:
# (10240, 180, 180, 3) (10240, 4)

# %% [markdown]
# ##splitting into train and test set

# %%
from sklearn.model_selection import train_test_split
train_data,test_data,train_labels,test_labels=train_test_split(train_data,train_labels,test_size=0.2,random_state=42)
train_data,val_data,train_labels,val_labels=train_test_split(train_data,train_labels,test_size=0.2,random_state=42)

# %% [markdown]
# ##pre trained model as cnn feature extractor

# %%
IMAGE_SIZE=[180,180]

# %%
xcep_model=Xception(input_shape=IMAGE_SIZE+[3],weights='imagenet',include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step

# %%
for layer in xcep_model.layers:
  layer.trainable=False

# %% [markdown]
# ##create sequential layers

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SeparableConv2D,BatchNormalization,GlobalAveragePooling2D,Dropout
custom_inception_model=Sequential([
    xcep_model,
    Dropout(0.5),
    GlobalAveragePooling2D(),
    Flatten(),
    BatchNormalization(),
    Dense(512,activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(256,activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128,activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(64,activation='relu'),
    Dropout(0.5),
    BatchNormalization(),
    Dense(4,activation='softmax')
],name="inception_cnn_model")

# %% [markdown]
# ##configuring the learning process

# %%
import tensorflow
METRICS=[tensorflow.keras.metrics.CategoricalAccuracy(name='acc'),
        tensorflow.keras.metrics.AUC(name='auc') ]
custom_inception_model.compile(optimizer='rmsprop',loss=tensorflow.losses.
                               CategoricalCrossentropy(),metrics=METRICS)

# %% [markdown]
# ##training the model

# %%
history=custom_inception_model.fit(train_data,train_labels,validation_data=(val_data,val_labels),epochs=11)
# Out:
# Epoch 1/11
# 205/205 [==============================] - 38s 130ms/step - loss: 1.3855 - acc: 0.4256 - auc: 0.6919 - val_loss: 0.8219 - val_acc: 0.6516 - val_auc: 0.8917
# Epoch 2/11
# 205/205 [==============================] - 22s 106ms/step - loss: 0.9146 - acc: 0.5910 - auc: 0.8501 - val_loss: 0.7096 - val_acc: 0.6583 - val_auc: 0.9059
# Epoch 3/11
# 205/205 [==============================] - 22s 106ms/step - loss: 0.7779 - acc: 0.6356 - auc: 0.8878 - val_loss: 0.6582 - val_acc: 0.7047 - val_auc: 0.9187
# Epoch 4/11
# 205/205 [==============================] - 21s 101ms/step - loss: 0.7381 - acc: 0.6644 - auc: 0.9002 - val_loss: 0.6232 - val_acc: 0.7108 - val_auc: 0.9274
# Epoch 5/11
# 205/205 [==============================] - 21s 101ms/step - loss: 0.6723 - acc: 0.6957 - auc: 0.9173 - val_loss: 0.5983 - val_acc: 0.7248 - val_auc: 0.9333
# Epoch 6/11
# 205/205 [==============================] - 22s 108ms/step - loss: 0.6372 - acc: 0.7207 - auc: 0.9268 - val_loss: 0.5869 - val_acc: 0.7407 - val_auc: 0.9371
# Epoch 7/11
# 205/205 [==============================] - 21s 103ms/step - loss: 0.6137 - acc: 0.7352 - auc: 0.9325 - val_loss: 0.5559 - val_acc: 0.7511 - val_auc: 0.9440
# Epoch 8/11
# 205/205 [==============================] - 22s 109ms/step - loss: 0.5891 - acc: 0.7508 - auc: 0.9387 - val_loss: 0.5400 - val_acc: 0.7669 - val_auc: 0.9474
# Epoch 9/11
# 205/205 [==============================] - 22s 108ms/step - loss: 0.5485 - acc: 0.7680 - auc: 0.9468 - val_loss: 0.5099 - val_acc: 0.7724 - val_auc: 0.9526
# Epoch 10/11
# 205/205 [==============================] - 23s 110ms/step - loss: 0.5314 - acc: 0.7812 - auc: 0.9502 - val_loss: 0.5019 - val_acc: 0.7828 - val_auc: 0.9550
# Epoch 11/11
# 205/205 [==============================] - 23s 112ms/step - loss: 0.5097 - acc: 0.7903 - auc: 0.9538 - val_loss: 0.4977 - val_acc: 0.7980 - val_auc: 0.9557

# %% [markdown]
# ##save the model

# %%
custom_inception_model.save('alz.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ##testing the model

# %%
from tensorflow.keras.models import load_model

# %%
from tensorflow.keras.preprocessing import image

# %%
from tensorflow.keras.applications.xception import preprocess_input

# %%
import numpy as np

# %%
model=load_model('/content/alz.h5')

# %%
img = image.load_img('/content/Alzheimer_s Dataset/test/VeryMildDemented/26 (46).jpg',target_size =(64,64))
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x64>

# %%
img=image.load_img(r'/content/Alzheimer_s Dataset/test/VeryMildDemented/26 (46).jpg',target_size=(180,180))
x=image.img_to_array(img)
import numpy as np
x=np.expand_dims(x,axis=0)
img_data=preprocess_input(x)
img_data.shape
model.predict(img_data)
output=np.argmax(model.predict(img_data),axis=1)
output
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 23ms/step
# array([3])

# %%
img = image.load_img('/content/Alzheimer_s Dataset/test/NonDemented/26 (74).jpg',target_size =(64,64))
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x64>

# %%
img=image.load_img(r'/content/Alzheimer_s Dataset/test/NonDemented/26 (74).jpg',target_size=(180,180))
x=image.img_to_array(img)
import numpy as np
x=np.expand_dims(x,axis=0)
img_data=preprocess_input(x)
img_data.shape
model.predict(img_data)
output=np.argmax(model.predict(img_data),axis=1)
output
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# array([2])

# %%
img = image.load_img('/content/Alzheimer_s Dataset/train/ModerateDemented/moderateDem10.jpg',target_size =(64,64))
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x64>

# %%
img=image.load_img(r'/content/Alzheimer_s Dataset/train/ModerateDemented/moderateDem10.jpg',target_size=(180,180))
x=image.img_to_array(img)
import numpy as np
x=np.expand_dims(x,axis=0)
img_data=preprocess_input(x)
img_data.shape
model.predict(img_data)
output=np.argmax(model.predict(img_data),axis=1)
output
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# array([1])

# %%
img = image.load_img('/content/Alzheimer_s Dataset/test/MildDemented/27 (11).jpg',target_size =(64,64))
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x64>

# %%
img=image.load_img(r'/content/Alzheimer_s Dataset/test/MildDemented/27 (11).jpg',target_size=(180,180))
x=image.img_to_array(img)
import numpy as np
x=np.expand_dims(x,axis=0)
img_data=preprocess_input(x)
img_data.shape
model.predict(img_data)
output=np.argmax(model.predict(img_data),axis=1)
output
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# array([0])

# %%
model.summary()
# Out:
# Model: "inception_cnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 6, 6, 2048)        20861480
#
#  dropout (Dropout)           (None, 6, 6, 2048)        0
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  batch_normalization_4 (Bat  (None, 2048)              8192
#  chNormalization)
#
#  dense (Dense)               (None, 512)               1049088
#
#  batch_normalization_5 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_6 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  batch_normalization_7 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  batch_normalization_8 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_4 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 22095340 (84.29 MB)
# Trainable params: 1227844 (4.68 MB)
# Non-trainable params: 20867496 (79.60 MB)
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt

# Plotting training & validation accuracy values
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['acc'], label='Train')
plt.plot(history.history['val_acc'], label='Validation')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

# Plotting training & validation AUC values
plt.subplot(1, 2, 2)
plt.plot(history.history['auc'], label='Train')
plt.plot(history.history['val_auc'], label='Validation')
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()
